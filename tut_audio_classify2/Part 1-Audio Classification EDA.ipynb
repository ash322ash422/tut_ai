# %% [markdown]
# ##### Audio Classification Using Machine Learning
# #####dataset url https://urbansounddataset.weebly.com/urbansound8k.html

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename='dog_bark.wav'

# %%
import IPython.display as ipd
import librosa
import librosa.display

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 389D-7F4E
#
#  Directory of C:\Users\hi\Desktop\projects\python_projects\ai_projects\tutorial\tut_ai\tut_audio_classify2
#
# 02/01/2025  10:08 PM    <DIR>          .
# 02/01/2025  09:56 PM    <DIR>          ..
# 02/01/2025  10:04 PM    <DIR>          .ipynb_checkpoints
# 05/20/2014  12:35 AM            62,218 dog_bark.wav
# 02/01/2025  09:58 PM           151,197 Part 2- Audio Classification Data Preprocessing And Model Creation.ipynb
# 02/01/2025  09:57 PM           146,754 Part 2- Audio Classification Data Preprocessing.ipynb
# 02/01/2025  10:06 PM         1,045,036 part1-Audio Classification EDA.ipynb
# 02/01/2025  10:03 PM    <DIR>          temp
#                4 File(s)      1,405,205 bytes
#                4 Dir(s)  140,540,616,704 bytes free

# %%
# NOTE TO ME: For this to work it needs numpy==2.0.2
### Dog Sound
plt.figure(figsize=(14,5))
data,sample_rate=librosa.load(filename)
librosa.display.waveshow(data,sr=sample_rate)
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
### Sound
filename='temp/UrbanSound8K/audio/fold2/14387-9-0-12.wav'
plt.figure(figsize=(14,5))
data,sample_rate=librosa.load(filename)
librosa.display.waveshow(data,sr=sample_rate)
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sample_rate
# Out:
# 22050

# %%
from scipy.io import wavfile as wav
wave_sample_rate, wave_audio=wav.read(filename)

# %%
wave_sample_rate
# Out:
# 44100

# %%
wave_audio
# Out:
# array([[ 158, -781],
#        [ 140, -737],
#        [ 164, -672],
#        ...,
#        [ 532, -622],
#        [ 462, -663],
#        [ 342, -616]], dtype=int16)

# %%
data # normalized data
# Out:
# array([-0.00708336, -0.00846365, -0.00429491, ..., -0.00069709,
#        -0.00092223, -0.00301317], dtype=float32)

# %%
import pandas as pd

metadata=pd.read_csv('temp/UrbanSound8K/metadata/UrbanSound8K.csv')
metadata.head(10)
# Out:
#       slice_file_name    fsID      start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032   0.000000   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263  58.500000  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263  60.500000  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263  63.000000  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263  68.500000  72.500000         1     5        2
# 5  100263-2-0-143.wav  100263  71.500000  75.500000         1     5        2
# 6  100263-2-0-161.wav  100263  80.500000  84.500000         1     5        2
# 7    100263-2-0-3.wav  100263   1.500000   5.500000         1     5        2
# 8   100263-2-0-36.wav  100263  18.000000  22.000000         1     5        2
# 9    100648-1-0-0.wav  100648   4.823402   5.471927         2    10        1
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# ...

# %%
### Check whether the dataset is imbalanced
metadata['class'].value_counts()
# Out:
# street_music        1000
# air_conditioner     1000
# jackhammer          1000
# engine_idling       1000
# drilling            1000
# children_playing    1000
# dog_bark            1000
# siren                929
# car_horn             429
# gun_shot             374
# Name: class, dtype: int64
